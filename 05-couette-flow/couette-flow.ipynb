# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#main loops
'''
# --- Euler ---
        v_euler_next = v_euler + h * f(t, v_euler)

        # --- RK2 ---
        k1_2 = f(t, v_rk2)
        k2_2 = f(t + h, v_rk2 + h * k1_2)
        v_rk2_next = v_rk2 + (h / 2.0) * (k1_2 + k2_2)

        # --- RK4 ---
        k1_4 = f(t, v_rk4)
        k2_4 = f(t + h/2.0, v_rk4 + (h/2.0) * k1_4)
        k3_4 = f(t + h/2.0, v_rk4 + (h/2.0) * k2_4)
        k4_4 = f(t + h, v_rk4 + h * k3_4)
        v_rk4_next = v_rk4 + (h / 6.0) * (k1_4 + 2*k2_4 + 2*k3_4 + k4_4)

        # Update states
        v_euler, v_rk2, v_rk4 = v_euler_next, v_rk2_next, v_rk4_next
        t += h
'''
